# %% [markdown]
# # 01 — Data Exploration
#
# Explore the raw landslide prediction datasets: landslide reports, ISRO landslide inventory, rainfall, DEM, soil, geology, landcover, and earthquake data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
print("Libraries loaded.")
